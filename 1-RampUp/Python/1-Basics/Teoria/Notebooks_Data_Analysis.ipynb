# %% [markdown]
# # Carga datos

# %%
lista = [5,3,2,1,6,8,9,0]

# %%
for i in range(20):
    lista = lista + lista

# %%
lista
# Out:
# [5,
#  3,
#  2,
#  1,
#  6,
#  8,
#  9,
#  0,
#  5,
#  3,
#  2,
#  1,
#  6,
#  8,
#  9,
#  0,
#  5,
#  3,
#  2,
#  1,
#  6,
#  8,
#  9,
#  0,
#  5,
#  3,
#  2,
#  1,
#  6,
#  8,
#  9,
#  0,
#  5,
#  3,
#  2,
#  1,
#  6,
#  8,
#  9,
#  0,
#  5,
#  3,
#  2,
#  1,
#  6,
#  8,
#  9,
#  0,
#  5,
#  3,
#  2,
#  1,
#  6,
#  8,
#  9,
#  0,
#  5,
#  3,
#  2,
#  1,
#  6,
#  8,
#  9,
#  0,
#  5,
#  3,
#  2,
#  1,
#  6,
#  8,
#  9,
#  0,
#  5,
#  3,
#  2,
#  1,
#  6,
#  8,
#  9,
#  0,
#  5,
#  3,
#  2,
#  1,
#  6,
#  8,
#  9,
#  0,
#  5,
#  3,
#  2,
#  1,
#  6,
#  8,
#  9,
#  0,
#  5,
#  3,
#  2,
#  1,
#  6,
#  8,
#  9,
#  0,
#  5,
#  3,
#  2,
#  1,
#  6,
#  8,
#  9,
#  0,
#  5,
#  3,
#  2,
#  1,
#  6,
#  8,
#  9,
#  0,
#  5,
#  3,
#  2,
#  1,
#  6,
#  8,
#  9,
#  0,
#  5,
#  3,
#  2,
#  1,
#  6,
#  8,
#  9,
#  0,
#  5,
#  3,
#  2,
#  1,
#  6,
#  8,
#  9,
#  0,
#  5,
#  3,
#  2,
#  1,
#  6,
#  8,
#  9,
#  0,
#  5,
#  3,
#  2,
#  1,
#  6,
#  8,
#  9,
#  0,
#  5,
#  3,
#  2,
#  1,
#  6,
#  8,
# ...

# %% [markdown]
# # Análisis Exploratorio

# %%
a = len(lista)  + 20000000000000000

# %%
max(lista)
# Out:
# 9

# %%
sum(lista)
# Out:
# 35651584

# %%
print(a)
# Out:
# 20000000008388608
